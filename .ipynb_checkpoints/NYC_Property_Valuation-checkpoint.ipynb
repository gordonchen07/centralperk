# %% [markdown]
# Using https://data.cityofnewyork.us/City-Government/Property-Valuation-and-Assessment-Data/yjxr-fw8i

# %%
import pandas as pd
from sodapy import Socrata
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
client = Socrata('data.cityofnewyork.us', None)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results = client.get("yjxr-fw8i", limit=2000)

# %%
df = pd.DataFrame.from_records(results)

# %%
df.head()
# Out:
#          bble boro block   lot                  owner bldgcl taxclass ltfront  \
# 0  1015571186    1  1557  1186       THE MARMARA INC.     RH        4       0
# 1  1017490066    1  1749    66   FINITE HOMES HOUSING     C7        2     100
# 2  1016801115    1  1680  1115             ERAN ELYOF     R4        2       0
# 3  1015341012    1  1534  1012           VALERIE ORAM     R4        2     110
# 4  2045220013    2  4522    13  WASHINGTON , CONSTANC     B3        1      25
#
#   ltdepth stories  fullval  avland   avtot exland   extot  \
# 0       0      31   422673   17504  190203      0       0
# 1     100       5  1629000  120150  733050      0  542696
# 2       0       8   158590    9397   71366      0   41626
# 3     202      45   137406    4597   61833   2350    2350
# 4     100       2   373000   10020   22380      0       0
#
#                 staddr    zip bldfront blddepth avland2  avtot2 period  \
# 0   301 EAST 94 STREET  10128        0        0   17504  137114  FINAL
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   bble                         2000 non-null   object
#  1   boro                         2000 non-null   object
#  2   block                        2000 non-null   object
#  3   lot                          2000 non-null   object
#  4   owner                        1929 non-null   object
#  5   bldgcl                       2000 non-null   object
#  6   taxclass                     2000 non-null   object
#  7   ltfront                      2000 non-null   object
#  8   ltdepth                      2000 non-null   object
#  9   stories                      1935 non-null   object
#  10  fullval                      2000 non-null   object
#  11  avland                       2000 non-null   object
#  12  avtot                        2000 non-null   object
# ...

# %%
df['block'] = pd.to_numeric(df['block'])

# %%
df[(df['boro']=='1') & (df['block'] > 2255)]
# Out:
# Empty DataFrame
# Columns: [bble, boro, block, lot, owner, bldgcl, taxclass, ltfront, ltdepth, stories, fullval, avland, avtot, exland, extot, staddr, zip, bldfront, blddepth, avland2, avtot2, period, year, valtype, borough, latitude, longitude, community_board, council_district, census_tract, bin, nta, geocoded_column, :@computed_region_efsh_h5xi, :@computed_region_f5dn_yrer, :@computed_region_yeji_bk3q, :@computed_region_92fq_4b7q, :@computed_region_sbqj_enih, ext, excd1, extot2, exland2, excd2, exmptcl, easement]
# Index: []

# %%
df['boro'].value_counts()
# Out:
# 1    1980
# 2      20
# Name: boro, dtype: int64

# %%
df['fullval'] = pd.to_numeric(df['fullval'])

# %%
df['fullval'].describe()
# Out:
# count    2.000000e+03
# mean     1.831221e+06
# std      7.214819e+06
# min      0.000000e+00
# 25%      1.620448e+05
# 50%      2.971650e+05
# 75%      8.927500e+05
# max      1.609200e+08
# Name: fullval, dtype: float64
